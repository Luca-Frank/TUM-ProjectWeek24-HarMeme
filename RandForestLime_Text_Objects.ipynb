# %%
import pandas as pd
import numpy as np
import lime
import sklearn
import sklearn.ensemble
import sklearn.metrics
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.datasets import load_digits
from tqdm import tqdm
import joblib

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Fetching data, training a classifier

# %% [markdown]
# For this tutorial, we'll be using the [20 newsgroups dataset](http://scikit-learn.org/stable/datasets/#the-20-newsgroups-text-dataset). In particular, for simplicity, we'll use a 2-class subset: atheism and christianity.

# %%
categories = [0, 1]
train = pd.read_csv("data/train_text_and_objects.csv", keep_default_na=False)
test = pd.read_csv("data/test_text_and_objects.csv", keep_default_na=False)
class_names = ['Not Harmful', 'Harmful']

# %% [markdown]
# Let's use the tfidf vectorizer, commonly used for text.

# %%
vectorizer = sklearn.feature_extraction.text.TfidfVectorizer(lowercase=False)
train_vectors = vectorizer.fit_transform(train["text_and_objects"])
test_vectors = vectorizer.transform(test["text_and_objects"])

# %% [markdown]
# Now, let's say we want to use random forests for classification. It's usually hard to understand what random forests are doing, especially with many trees.

# %%
rf = sklearn.ensemble.RandomForestClassifier(
    n_estimators=500,     # Number of trees in the forest.
    max_depth=30,         # Maximum depth of the trees.
    max_features="sqrt",
    min_samples_split=5,  # Minimum number of samples required to split an internal node.
    min_samples_leaf=1,   # Minimum number of samples required to be at a leaf node.
    bootstrap=True,       # Use bootstrap samples when building trees.
    oob_score=True,       # Use out-of-bag samples to estimate the generalization accuracy.
    n_jobs=-1,            # Use all cores available.
    random_state=42,      # Random seed.
    class_weight="balanced" # Use balanced class weights to adjust for imbalanced dataset.
)
rf.fit(train_vectors, train["binary_labels"])
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=30,
#                        min_samples_split=5, n_estimators=500, n_jobs=-1,
#                        oob_score=True, random_state=42)

# %%
pred = rf.predict(test_vectors)
print(f' Accuracy {sklearn.metrics.accuracy_score(test["binary_labels"], pred)}')
print(f' Precision {sklearn.metrics.precision_score(test["binary_labels"], pred, average="binary")}')
print(f' Recall {sklearn.metrics.recall_score(test["binary_labels"], pred, average="binary")}')
print(f' F1-Score {sklearn.metrics.f1_score(test["binary_labels"], pred, average="binary")}')
# Out:
#  Accuracy 0.788135593220339
#  Precision 0.6601307189542484
#  Recall 0.8145161290322581
#  F1-Score 0.7292418772563177

# %% [markdown]
# ## Explaining predictions using lime

# %% [markdown]
# Lime explainers assume that classifiers act on raw text, but sklearn classifiers act on vectorized representation of texts. For this purpose, we use sklearn's pipeline, and implement ````predict_proba```` on raw_text lists.

# %%
from sklearn.pipeline import make_pipeline
c = make_pipeline(vectorizer, rf)

# %%
print(c.predict_proba([test["text_and_objects"][0]]))
# Out:
# [[0.53060366 0.46939634]]

# %% [markdown]
# Now we create an explainer object. We pass the ````class_names```` as an argument for prettier display.

# %%
from lime.lime_text import LimeTextExplainer
explainer = LimeTextExplainer(class_names=class_names)

# %% [markdown]
# We then generate an explanation with at most 6 features for an arbitrary document in the test set.

# %%
idx = 83
exp = explainer.explain_instance(test["text_and_objects"][idx], c.predict_proba, num_features=10)
print('Document id: %d' % idx)
print('Probability(Harmful) =', c.predict_proba([test["text_and_objects"][idx]])[0, 1])
print('True class: %s' % class_names[test["binary_labels"][idx]])
# Out:
# Document id: 83
# Probability(Harmful) = 0.5902344201778397
# True class: Harmful

# %%
df_pred = []
for idx in range(0,len(test)):
    exp = explainer.explain_instance(test["text_and_objects"][idx], c.predict_proba, num_features=2)
    print('Document id: %d' % idx)
    dict_pred = {
        "id": idx,
        "Prob (Harmful)": c.predict_proba([test["text_and_objects"][idx]])[0, 1],
        "True Class": class_names[test["binary_labels"][idx]],
        "Explainers":exp.as_list()
    }
    
    df_pred.append(dict_pred)
# Out:
# Document id: 0
# Document id: 1
# Document id: 2
# Document id: 3
# Document id: 4
# Document id: 5
# Document id: 6
# Document id: 7
# Document id: 8
# Document id: 9
# Document id: 10
# Document id: 11
# Document id: 12
# Document id: 13
# Document id: 14
# Document id: 15
# Document id: 16
# Document id: 17
# Document id: 18
# Document id: 19
# Document id: 20
# Document id: 21
# Document id: 22
# Document id: 23
# Document id: 24
# Document id: 25
# Document id: 26
# Document id: 27
# Document id: 28
# Document id: 29
# Document id: 30
# Document id: 31
# Document id: 32
# Document id: 33
# Document id: 34
# Document id: 35
# Document id: 36
# Document id: 37
# Document id: 38
# Document id: 39
# Document id: 40
# Document id: 41
# Document id: 42
# Document id: 43
# Document id: 44
# Document id: 45
# Document id: 46
# Document id: 47
# Document id: 48
# Document id: 49
# Document id: 50
# Document id: 51
# Document id: 52
# Document id: 53
# Document id: 54
# Document id: 55
# Document id: 56
# Document id: 57
# Document id: 58
# Document id: 59
# Document id: 60
# Document id: 61
# Document id: 62
# Document id: 63
# Document id: 64
# Document id: 65
# Document id: 66
# Document id: 67
# Document id: 68
# Document id: 69
# Document id: 70
# Document id: 71
# Document id: 72
# Document id: 73
# Document id: 74
# Document id: 75
# Document id: 76
# Document id: 77
# Document id: 78
# Document id: 79
# Document id: 80
# Document id: 81
# Document id: 82
# Document id: 83
# Document id: 84
# Document id: 85
# Document id: 86
# Document id: 87
# Document id: 88
# Document id: 89
# Document id: 90
# Document id: 91
# Document id: 92
# Document id: 93
# Document id: 94
# Document id: 95
# Document id: 96
# Document id: 97
# Document id: 98
# Document id: 99
# Document id: 100
# Document id: 101
# Document id: 102
# Document id: 103
# Document id: 104
# Document id: 105
# Document id: 106
# Document id: 107
# Document id: 108
# Document id: 109
# Document id: 110
# Document id: 111
# Document id: 112
# Document id: 113
# Document id: 114
# Document id: 115
# Document id: 116
# Document id: 117
# Document id: 118
# Document id: 119
# Document id: 120
# Document id: 121
# Document id: 122
# Document id: 123
# Document id: 124
# Document id: 125
# Document id: 126
# Document id: 127
# Document id: 128
# Document id: 129
# Document id: 130
# Document id: 131
# Document id: 132
# Document id: 133
# Document id: 134
# Document id: 135
# Document id: 136
# Document id: 137
# Document id: 138
# Document id: 139
# Document id: 140
# Document id: 141
# Document id: 142
# Document id: 143
# Document id: 144
# Document id: 145
# Document id: 146
# Document id: 147
# Document id: 148
# Document id: 149
# Document id: 150
# Document id: 151
# Document id: 152
# Document id: 153
# Document id: 154
# Document id: 155
# Document id: 156
# Document id: 157
# Document id: 158
# Document id: 159
# Document id: 160
# Document id: 161
# Document id: 162
# Document id: 163
# Document id: 164
# Document id: 165
# Document id: 166
# Document id: 167
# Document id: 168
# Document id: 169
# Document id: 170
# Document id: 171
# Document id: 172
# Document id: 173
# Document id: 174
# Document id: 175
# Document id: 176
# Document id: 177
# Document id: 178
# Document id: 179
# Document id: 180
# Document id: 181
# Document id: 182
# Document id: 183
# Document id: 184
# Document id: 185
# Document id: 186
# Document id: 187
# Document id: 188
# Document id: 189
# Document id: 190
# Document id: 191
# Document id: 192
# Document id: 193
# Document id: 194
# Document id: 195
# Document id: 196
# Document id: 197
# Document id: 198
# Document id: 199
# Document id: 200
# Document id: 201
# Document id: 202
# Document id: 203
# Document id: 204
# Document id: 205
# Document id: 206
# Document id: 207
# Document id: 208
# Document id: 209
# Document id: 210
# Document id: 211
# Document id: 212
# Document id: 213
# Document id: 214
# Document id: 215
# Document id: 216
# Document id: 217
# Document id: 218
# Document id: 219
# Document id: 220
# Document id: 221
# Document id: 222
# Document id: 223
# Document id: 224
# Document id: 225
# Document id: 226
# Document id: 227
# Document id: 228
# Document id: 229
# Document id: 230
# Document id: 231
# Document id: 232
# Document id: 233
# Document id: 234
# Document id: 235
# Document id: 236
# Document id: 237
# Document id: 238
# Document id: 239
# Document id: 240
# Document id: 241
# Document id: 242
# Document id: 243
# Document id: 244
# Document id: 245
# Document id: 246
# Document id: 247
# Document id: 248
# Document id: 249
# Document id: 250
# Document id: 251
# Document id: 252
# Document id: 253
# Document id: 254
# Document id: 255
# Document id: 256
# Document id: 257
# Document id: 258
# Document id: 259
# Document id: 260
# Document id: 261
# Document id: 262
# Document id: 263
# Document id: 264
# Document id: 265
# Document id: 266
# Document id: 267
# Document id: 268
# Document id: 269
# Document id: 270
# Document id: 271
# Document id: 272
# Document id: 273
# Document id: 274
# Document id: 275
# Document id: 276
# Document id: 277
# Document id: 278
# Document id: 279
# Document id: 280
# Document id: 281
# Document id: 282
# Document id: 283
# Document id: 284
# Document id: 285
# Document id: 286
# Document id: 287
# Document id: 288
# Document id: 289
# Document id: 290
# Document id: 291
# Document id: 292
# Document id: 293
# Document id: 294
# Document id: 295
# Document id: 296
# Document id: 297
# Document id: 298
# Document id: 299
# Document id: 300
# Document id: 301
# Document id: 302
# Document id: 303
# Document id: 304
# Document id: 305
# Document id: 306
# Document id: 307
# Document id: 308
# Document id: 309
# Document id: 310
# Document id: 311
# Document id: 312
# Document id: 313
# Document id: 314
# Document id: 315
# Document id: 316
# Document id: 317
# Document id: 318
# Document id: 319
# Document id: 320
# Document id: 321
# Document id: 322
# Document id: 323
# Document id: 324
# Document id: 325
# Document id: 326
# Document id: 327
# Document id: 328
# Document id: 329
# Document id: 330
# Document id: 331
# Document id: 332
# Document id: 333
# Document id: 334
# Document id: 335
# Document id: 336
# Document id: 337
# Document id: 338
# Document id: 339
# Document id: 340
# Document id: 341
# Document id: 342
# Document id: 343
# Document id: 344
# Document id: 345
# Document id: 346
# Document id: 347
# Document id: 348
# Document id: 349
# Document id: 350
# Document id: 351
# Document id: 352
# Document id: 353

# %%
df_pred = pd.DataFrame(df_pred)
df_pred["Prob Class"] = np.where(df_pred["Prob (Harmful)"]>=0.5,"Harmful","Not Harmful")
df_pred
# Out:
#       id  Prob (Harmful)   True Class  \
# 0      0        0.469396  Not Harmful
# 1      1        0.590845  Not Harmful
# 2      2        0.660960  Not Harmful
# 3      3        0.683989  Not Harmful
# 4      4        0.743884  Not Harmful
# ..   ...             ...          ...
# 349  349        0.320137  Not Harmful
# 350  350        0.516853  Not Harmful
# 351  351        0.333345  Not Harmful
# 352  352        0.374979  Not Harmful
# 353  353        0.328495  Not Harmful
#
#                                             Explainers   Prob Class
# 0    [(trump, 0.1169529502502709), (2020, -0.070386...  Not Harmful
# 1    [(trump, 0.15296144353417013), (biden, 0.07485...      Harmful
# 2    [(trump, 0.16356755419783037), (tie, 0.0670559...      Harmful
# 3    [(trump, 0.1693199734990199), (tie, 0.07413646...      Harmful
# 4    [(trump, 0.1438243517955391), (china, 0.090579...      Harmful
# ..                                                 ...          ...
# 349  [(day, -0.0900714999179774), (person, 0.044032...  Not Harmful
# 350  [(say, 0.06906346401770386), (person, 0.044963...      Harmful
# 351  [(day, -0.08714002530779635), (person, 0.03286...  Not Harmful
# 352  [(meme, -0.07183836191348332), (person, 0.0375...  Not Harmful
# 353  [(quarantine, -0.06436318137262395), (vaccine,...  Not Harmful
#
# [354 rows x 5 columns]

# %%
explainer_list=[]
c=0
for i in df_pred["Explainers"]:
    for k in i:
        explainer_dict={
            "id": c,
            "word":k[0],
            "value":k[1]
        }
        explainer_list.append(explainer_dict)
    c+=1
        
        
explainer_list=pd.DataFrame(explainer_list)
explainer_list = explainer_list.merge(df_pred, on="id")
explainer_list
# Out:
#       id        word     value  Prob (Harmful)   True Class  \
# 0      0       trump  0.116953        0.469396  Not Harmful
# 1      0        2020 -0.070387        0.469396  Not Harmful
# 2      1       trump  0.152961        0.590845  Not Harmful
# 3      1       biden  0.074857        0.590845  Not Harmful
# 4      2       trump  0.163568        0.660960  Not Harmful
# ..   ...         ...       ...             ...          ...
# 703  351      person  0.032861        0.333345  Not Harmful
# 704  352        meme -0.071838        0.374979  Not Harmful
# 705  352      person  0.037536        0.374979  Not Harmful
# 706  353  quarantine -0.064363        0.328495  Not Harmful
# 707  353     vaccine  0.049207        0.328495  Not Harmful
#
#                                             Explainers   Prob Class
# 0    [(trump, 0.1169529502502709), (2020, -0.070386...  Not Harmful
# 1    [(trump, 0.1169529502502709), (2020, -0.070386...  Not Harmful
# 2    [(trump, 0.15296144353417013), (biden, 0.07485...      Harmful
# 3    [(trump, 0.15296144353417013), (biden, 0.07485...      Harmful
# 4    [(trump, 0.16356755419783037), (tie, 0.0670559...      Harmful
# ..                                                 ...          ...
# 703  [(day, -0.08714002530779635), (person, 0.03286...  Not Harmful
# 704  [(meme, -0.07183836191348332), (person, 0.0375...  Not Harmful
# 705  [(meme, -0.07183836191348332), (person, 0.0375...  Not Harmful
# 706  [(quarantine, -0.06436318137262395), (vaccine,...  Not Harmful
# 707  [(quarantine, -0.06436318137262395), (vaccine,...  Not Harmful
#
# [708 rows x 7 columns]

# %%
harmful_count = explainer_list.groupby(['word', 'Prob Class']).size().reset_index(name='count')
harmful_count = harmful_count.pivot_table(index='word', columns='Prob Class', values='count', fill_value=0)
harmful_count.columns = ['Not Harmful', 'Harmful']
harmful_count.reset_index(inplace=True)

harmful_count["count"] = harmful_count["Not Harmful"]+harmful_count["Harmful"]
harmful_count=harmful_count.sort_values(by="count", ascending=False).head(10)
#harmful_count = harmful_count.pivot_table(index='word', values=['Not Harmful', 'Harmful'], aggfunc='sum')
harmful_count
# Out:
#            word  Not Harmful  Harmful  count
# 85       person         52.0    116.0  168.0
# 115       trump         80.0      4.0   84.0
# 109         tie         59.0     10.0   69.0
# 120       virus         22.0      9.0   31.0
# 91   quarantine          0.0     19.0   19.0
# 5          2020          2.0     16.0   18.0
# 37          dog          0.0     18.0   18.0
# 38       donald         15.0      1.0   16.0
# 32          day          0.0     13.0   13.0
# 80         meme          3.0     10.0   13.0

# %% [markdown]
# ## Visualizing explanations

# %%
harmful_long = pd.melt(harmful_count, id_vars='word', var_name='Result', value_name='Count')
harmful_long.sort_values(by="word")
# Out:
#           word       Result  Count
# 25        2020        count   18.0
# 5         2020  Not Harmful    2.0
# 15        2020      Harmful   16.0
# 8          day  Not Harmful    0.0
# 18         day      Harmful   13.0
# 28         day        count   13.0
# 26         dog        count   18.0
# 6          dog  Not Harmful    0.0
# 16         dog      Harmful   18.0
# 27      donald        count   16.0
# 7       donald  Not Harmful   15.0
# 17      donald      Harmful    1.0
# 29        meme        count   13.0
# 9         meme  Not Harmful    3.0
# 19        meme      Harmful   10.0
# 20      person        count  168.0
# 0       person  Not Harmful   52.0
# 10      person      Harmful  116.0
# 4   quarantine  Not Harmful    0.0
# 24  quarantine        count   19.0
# 14  quarantine      Harmful   19.0
# 12         tie      Harmful   10.0
# 22         tie        count   69.0
# 2          tie  Not Harmful   59.0
# 11       trump      Harmful    4.0
# 21       trump        count   84.0
# 1        trump  Not Harmful   80.0
# 23       virus        count   31.0
# 3        virus  Not Harmful   22.0
# 13       virus      Harmful    9.0

# %%
# Correcting the code snippet provided by the user and plotting the barplot accordingly
# First, we'll need to convert the DataFrame from wide to long format

# For the given data, we can use 'pd.melt' instead of 'pd.wide_to_long' for simplici
# Now, let's create the barplot with seaborn
plt.figure(figsize=(10, 6))
sns.barplot(y='word', x='Count', hue='Result', data=harmful_long[harmful_long["Result"]!="count"], palette=['blue', 'red'])

# Adding legend and labels
plt.legend(title='Result')
plt.ylabel('Word')
plt.xlabel('Count')
plt.title('Harmful vs Not Harmful Counts for Words and Objects')
plt.xticks(rotation=45)  # Rotating the x-axis labels for better readability

# Display the plot
plt.savefig("plots/RF/3.Top10HarmfulHarmlessWordAndObjectsCount.jpeg")

# %%
exp_val =explainer_list[["word","value"]].groupby("word").mean("value")
exp_val["dir"] = np.where(exp_val["value"]>=0,"positive","negative")

top10=harmful_long[harmful_long["Result"]!="count"][["word"]].drop_duplicates()

top10 = top10.merge(exp_val, how="inner",on="word")


plt.figure(figsize=(10, 6))
sns.barplot(y='word', x='value',hue="dir" , data=top10, palette=["red","green"])

# Adding legend and labels
plt.legend(title='Result')
plt.ylabel('Word')
plt.xlabel('Count')
plt.title('Harmful vs Not Harmful Counts for Words and Objects')
plt.xticks(rotation=45)  # Rotating the x-axis labels for better readability

# Display the plot
plt.savefig("plots/RF/3.Top10HarmfulHarmlessWordAndObjectsValues.jpeg")

# %%
exp_p = exp_val[exp_val["dir"]=="positive"].sort_values("value",ascending=False).head(10)
exp_n = exp_val[exp_val["dir"]=="negative"].sort_values("value",ascending=True).head(10)
exp_n["value"]=exp_n["value"]*-1

plt.figure(figsize=(10, 6))
sns.barplot(y=exp_p.index, x='value',hue="dir" , data=exp_p, palette=["red"])

# Adding legend and labels
plt.legend(title='Result')
plt.ylabel('Word')
plt.xlabel('Count')
plt.title('Top 10 Words and Objects by average explaining value for Meme being harmful')
plt.xticks(rotation=45)  # Rotating the x-axis labels for better readability

# Display the plot
plt.savefig("plots/RF/3.Positive_Top10WordsAndObjectsByValues.jpeg")

plt.figure(figsize=(10, 6))
sns.barplot(y=exp_n.index, x='value',hue="dir" , data=exp_n, palette=["green"])

# Adding legend and labels
plt.legend(title='Result')
plt.ylabel('Word')
plt.xlabel('Count')
plt.title('Top 10 Words and Objects by average explaining value for Meme being harmless')
plt.xticks(rotation=45)  # Rotating the x-axis labels for better readability

# Display the plot
plt.savefig("plots/RF/3.Negative_Top10WordsAndObjectsByValues.jpeg")
